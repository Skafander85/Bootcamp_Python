# %%
#importy
from IPython.display import clear_output
import random
print("Witaj w mojej grze chujku! Kółko i krzyżyk! \n\n")

# Set the game up here
#rysuje planszę
def display_board(board): 
    #clear_output() - działa tylko w jupiter notes
    print (' {7} | {8} | {9} \n --------- \n {4} | {5} | {6}  \n --------- \n {1} | {2} | {3} '.format(board[0],board[1],board[2],board[3],board[4],board[5],board[6],board[7],board[8],board[9]))


#losuje kto gra pierwszy
def choose_first():
    random_num = random.randint(1,100)
    print ('Ten chujek gra pierwszy: ')
    if random_num%2 == 0:
        
        return 'Player1'
    else:
        return 'Player2'
    pass    

#Wybierz czym gra gracz
def player_input():
    znak = ""    
    print ("Czym grasz mistrzu?")
    while len(znak) == 0:
        wybor = input("Wpisz x lub o tutaj: ")
        if wybor.lower() == 'x':
            znak = wybor.upper()
            break
        elif wybor.lower()  == 'o':
            znak = wybor.upper()
            break
        else:
            print('\n Źle wpisałeś, śmieciu! Dawaj jeszcze raz!')
            continue
    return znak

#wstawia znak gracza na plansze
def place_marker(board, marker,position): 
    board[int(position)] = marker
    return board
    pass

#sprawdza czy gracz wygrał, sprawdza znaki
def win_check(board, mark):
    winlist = [mark,mark,mark]
    winline =(board[1:4],board[4:7],board[7:10],board[1:10:4],board[1:10:4],board[3:9:2],board[1:9:3],board[2:9:3],board[3:10:3])
    
    for pos in winline:
        if pos == winlist:
            return True
            break
       
    return False
    pass

#sprawdzam czy wybrane miejsce jest wolne
def space_check(board, position):
    if board[int(position)] == " ":
        return True
    else:
        return False

#sprawdzam czy plansza jest zapełniona
def full_board_check(board):
    if " " in board:
        return False
    else:
        return True
    pass

#wybór pola przez gracza
def player_choice(board):
    position = 0
    while position == 0:
        while True: #tu upewniam sie ze wwpisal liczbe a nie litere aby mi nie wyjablo bledu
            try:
                wybor = int(input("\n Wpisz pozycję gdzie chcesz ustawić znak, śmieciu: "))
                break
            except:
                print("\n Wpisz liczbę, L I C Z B Ę!")
            
        if int(wybor) in range(1,10): #sparawdzam czy liba w przedziale 1 - 9
            if space_check(board,int(wybor)):
                position = wybor
                return  position
                break
            else:
                print('\n To miejsce jest już zajęte cwelu! Dawaj jeszcze raz!')
                continue
        else:
            print('\n Wpisz liczbę od 1 do 9 leszczu!')
            continue
            
#czy powtórzyć grę? 
def replay():
    print("\n Chcecie zagrać jeszcze raz Śmiecie?")
    l_powtorzen = 0
    wynik = 0
    while wynik == 0:
        wybor = input("Wpisz T jeśli tak, N jeśli nie:")
        if wybor.lower() == "t":
            return  True
            break
        if wybor.lower() == 'n' or l_powtorzen == 3: #jak 3 razy wpisze zl;e to wwylaczy sie
            return  False
            break
        else:
            l_powtorzen += 1
            print('\n\n Wpisz T lub N, czego nie rozumiesz?!')
            continue


#while True:
start = 0
while start == 0:
    board = ['#',' ',' ',' ',' ',' ',' ',' ',' ',' ']
    
    #pass
    player1 = choose_first()#Losuje gracza
    if player1 == 'Player1': # wylosowany jako pierszy gracz
        player2 = 'Player2'
    else:
        player2 = 'Player1'
        
    print(player1)
    marker = player_input() # pytam o znak jakim chce grac gracz
    turn = 1
    if marker == 'X':
        marker2 = 'O'
    else:
        marker2 = 'X'
    
    game_on = 1
    #while game_on:
    while game_on == 1:

        #Player 1 Turn
        while turn == 1:
            display_board(board) #wyswietlam plansze
            print('Wybiera {}, grający {}'.format(player1, marker)) 
            position = player_choice(board)# pytam o pozycje
            if space_check(board, position): # sprawdzam czy nie zajete
                board = place_marker(board, marker, position) # umieszczam znak i sprawdzam czy wygral i czy nie zapelnil planszy
                if win_check(board, marker):
                    wygrywa = [marker,player1]
                    game_on = 0
                    break
                elif full_board_check(board):
                    wygrywa = 'Remis'
                    game_on = 0
                    break
                           
            turn = 2 # przerzucam na drugiego gracza
            
        # Player2's turn.
        while turn == 2:
            display_board(board)
            print('Wybiera {}, grający {}'.format(player2, marker2))
            position = player_choice(board)
            if space_check(board, position):
                board = place_marker(board, marker2, position)
                if win_check(board, marker2):
                    wygrywa = [marker2,player2]
                    game_on = 0
                    break
                elif full_board_check(board):
                    wygrywa = 'Remis'
                    game_on = 0
                    break
            turn = 1 # jak nie wygral i nie pelne to wracan na pierwszy
                

        #pass    

    
    #if not replay(): pytam o replay
    #break
    display_board(board)
    if wygrywa == 'Remis':
        print('Remis')
    else:        
        print ('\n WYgrał śmieć:{}, który grał:{}'.format(wygrywa[1],wygrywa[0]))
    if replay() != True:
        start = 1
        break
# Out:
#    |   |
#  ---------
#    | O | O
#  ---------
#  X | X | X
#
#  WYgrał śmieć:Player2, który grał:X
#
#  Chcecie zagrać jeszcze raz Śmiecie?
# Wpisz T jeśli tak, N jeśli nie:n
